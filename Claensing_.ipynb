# %% [markdown]
# <a href="https://colab.research.google.com/github/Worachet-Ch/data_viz_2022/blob/main/Claensing_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import missingno as mno
from sklearn import linear_model
# %matplotlib inline
import numpy as np
from pandas.api.types import is_numeric_dtype

# %%
import pandas as pd
import os
from google.colab import drive #เชื่อม Google drive
drive.mount('/content/drive')
path = '/content/drive/My Drive/project' #เข้า drive
data_file_path = os.path.join(path,'dataset.csv') #ไปที่ไฟล์ confirmed-cases-since-280265.csv
data = pd.read_csv(data_file_path) #อ่านไฟล์ csv
# Out:
# Mounted at /content/drive

# %%
data
# Out:
#        No.        LabNo  Sex  AgeSYear  Enose  Overall  Body shape age  \
# 0     50.0  2.01809E+11    2        58    NaN      NaN             NaN
# 1     57.0  2.01809E+11    2        57    NaN      NaN             NaN
# 2     86.0   2.0181E+11    2        24    NaN      NaN             NaN
# 3    104.0   2.0181E+11    2        62    NaN      NaN             NaN
# 4    109.0  2.01811E+11    2        86    NaN      NaN             NaN
# ..     ...          ...  ...       ...    ...      ...             ...
# 418    NaN          V14    2        25    NaN      NaN             NaN
# 419    NaN          V17    2        31    NaN      NaN             NaN
# 420    NaN          V19    2        32    NaN      NaN             NaN
# 421    NaN          V21    1        29    NaN      NaN             NaN
# 422    NaN          V22    2        31    NaN      NaN             NaN
#
#      Kidney  Heart  Liver  ...  071_HbA1c     CK   LD-P   AMY7   TP1  DBIL  \
# ...

# %% [markdown]
# ### MANUAL

# %%
data1 = data[data['BMI']>=15] 
data1 = data1[data1['BMI']<31]
data1 = data1[data1['Systolic']>=80] 
data1 = data1[data1['Systolic']<=160] 
data1 = data1[data1['Diastolic']>=50]
data1 = data1[data1['Diastolic']<=100]
data1 = data1[data1['abdominal circumference']>=60]
data1 = data1[data1['abdominal circumference']<=105]
data1 = data1[data1['002_BUN']>=5]
data1 = data1[data1['002_BUN']<=30]
data1 = data1[data1['003_Creatinine']>=0.4]
data1 = data1[data1['003_Creatinine']<=2]
data1 = data1[data1['004_Uric Acid']>=2.7]
data1 = data1[data1['004_Uric Acid']<=7]
data1 = data1[data1['005_Cholesterol']>=50]
data1 = data1[data1['005_Cholesterol']<=260]
data1 = data1[data1['006_Triglyceride']>=50]
data1 = data1[data1['006_Triglyceride']<=400]
data1 = data1[data1['008_HDL-C']>=20]
data1 = data1[data1['008_HDL-C']<=90]
data1 = data1[data1['009_LDL']<=190]
data1 = data1[data1['010_AST']<=60]
data1 = data1[data1['012_ALT']<=80]
data1 = data1[data1['013_Alkaline Phos']>=50]
data1 = data1[data1['013_Alkaline Phos']<=350]
data1 = data1[data1['071_HbA1c']>=3]
data1 = data1[data1['071_HbA1c']<=8]
data1 = data1[data1['CK']>=35.36]
data1 = data1[data1['CK']<=176.8]
data1 = data1[data1['LD-P']>=89] # LD-P ยังไม่ใส่ < 221 เนื่องจากยังสงสัยข้อมูล ถ้าใส่จะเหลือเพียง 1 ค่า 
data1 = data1[data1['GGT']<=120]
data1
# Out:
#        No.        LabNo  Sex  AgeSYear  Enose  Overall  Body shape age  \
# 1     57.0  2.01809E+11    2        57    NaN      NaN             NaN
# 13   191.0  2.01901E+11    1        46    NaN      NaN             NaN
# 22   258.0  2.01901E+11    2        30    NaN      NaN             NaN
# 24   320.0  2.01901E+11    2        22    NaN      NaN             NaN
# 25   344.0  2.01901E+11    2        47    NaN      NaN             NaN
# ..     ...          ...  ...       ...    ...      ...             ...
# 153  878.0  2.01902E+11    2        58    NaN      NaN             NaN
# 154  882.0  2.01902E+11    2        32    NaN      NaN             NaN
# 156  895.0  2.01903E+11    2        38    NaN      NaN             NaN
# 165  942.0  2.01903E+11    1        50    NaN      NaN             NaN
# 169  978.0  2.01903E+11    1        60    NaN      NaN             NaN
#
#      Kidney  Heart  Liver  ...  071_HbA1c     CK   LD-P   AMY7   TP1  DBIL  \
# ...

# %% [markdown]
# ### LOOP
# ปล.ยังคิดไม่ออก
